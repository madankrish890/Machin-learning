# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\lenovo\\OneDrive\\data science\\Priyanka DS\\climate_data.csv")
data
# Out:
#               date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0       01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1       02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2       03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3       04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4       05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
# ...            ...   ...   ...   ...     ...   ...  ...   ...    ...     ...
# 589260  27-12-2020  25.2  31.2  29.2    74.0   0.0  1.4   4.0  280.0     2.0
# 589261  28-12-2020  25.3  31.6  28.1    78.0   NaN  3.0  12.0  260.0     2.0
# 589262  29-12-2020  24.6  32.3  28.4    81.0   NaN  6.5   5.0  260.0     2.0
# 589263  30-12-2020  25.2  32.6  28.4    80.0   0.0  2.4   7.0  260.0     2.0
# 589264  31-12-2020  24.3  32.0  26.7    86.0  26.6  5.8   7.0  350.0     2.0
#
#        ddd_car  station_id
# ...

# %%
#understanding data

# %%
data.nunique()
# Out:
# date          4018
# Tn             218
# Tx             254
# Tavg           202
# RH_avg          81
# RR            1734
# ss             188
# ff_x            70
# ddd_x          373
# ff_avg          57
# ddd_car          9
# station_id     173
# dtype: int64

# %%
data.dtypes
# Out:
# date           object
# Tn            float64
# Tx            float64
# Tavg          float64
# RH_avg        float64
# RR            float64
# ss            float64
# ff_x          float64
# ddd_x         float64
# ff_avg        float64
# ddd_car        object
# station_id      int64
# dtype: object

# %%
data.describe()
# Out:
#                   Tn             Tx           Tavg         RH_avg  \
# count  565882.000000  551529.000000  544160.000000  541083.000000
# mean       23.312111      31.528955      26.855475      82.489365
# std         2.280687       2.311659       1.939656      14.337669
# min         0.000000       0.000000       0.000000      24.000000
# 25%        23.000000      30.500000      26.200000      79.000000
# 50%        24.000000      31.800000      27.200000      83.000000
# 75%        25.000000      33.000000      28.000000      87.000000
# max       246.000000     334.000000     141.600000    7520.000000
#
#                   RR             ss           ff_x          ddd_x  \
# count  463881.000000  545544.000000  579051.000000  576137.000000
# mean        8.680760       5.083199       4.709601     188.488325
# std        17.928752       3.261586       2.612285     107.657452
# min        -1.000000       0.000000       0.000000       0.000000
# ...

# %%
data.isnull().sum()
# Out:
# date               0
# Tn             23383
# Tx             37736
# Tavg           45105
# RH_avg         48182
# RR            125384
# ss             43721
# ff_x           10214
# ddd_x          13128
# ff_avg         10127
# ddd_car        13739
# station_id         0
# dtype: int64

# %%
data.shape
# Out:
# (589265, 12)

# %%
data['date']=pd.to_datetime(data['date'],errors='coerce')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3292\2536266494.py:1: UserWarning: Parsing '13-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['date']=pd.to_datetime(data['date'],errors='coerce')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3292\2536266494.py:1: UserWarning: Parsing '14-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['date']=pd.to_datetime(data['date'],errors='coerce')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3292\2536266494.py:1: UserWarning: Parsing '15-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['date']=pd.to_datetime(data['date'],errors='coerce')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3292\2536266494.py:1: UserWarning: Parsing '16-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
data.dtypes
# Out:
# date          datetime64[ns]
# Tn                   float64
# Tx                   float64
# Tavg                 float64
# RH_avg               float64
# RR                   float64
# ss                   float64
# ff_x                 float64
# ddd_x                float64
# ff_avg               float64
# ddd_car               object
# station_id             int64
# dtype: object

# %%
data['ddd_car']=pd.to_numeric(data['ddd_car'],errors='coerce')

# %%
data.dtypes
# Out:
# date          datetime64[ns]
# Tn                   float64
# Tx                   float64
# Tavg                 float64
# RH_avg               float64
# RR                   float64
# ss                   float64
# ff_x                 float64
# ddd_x                float64
# ff_avg               float64
# ddd_car              float64
# station_id             int64
# dtype: object

# %%
print('percentage of missing values in Tn',data.Tn.isnull().sum()/len(data.Tn)*100,'%')
print('percentage of missing values in Tx',data.Tx.isnull().sum()/len(data.Tx)*100,'%')
print('percentage of missing values in Tavg',data.Tavg.isnull().sum()/len(data.Tavg)*100,'%')
print('percentage of missing values in RH_avg',data.RH_avg.isnull().sum()/len(data.RH_avg )*100,'%')
print('percentage of missing values in RR',data.RR.isnull().sum()/len(data.RR)*100,'%')
print('percentage of missing values in ss',data.ss.isnull().sum()/len(data.ss)*100,'%')
print('percentage of missing values in ff_x',data.ff_x.isnull().sum()/len(data.ff_x)*100,'%')
print('percentage of missing values in ddd_x',data.ddd_x.isnull().sum()/len(data.ddd_x)*100,'%')
print('percentage of missing values in Tn',data.Tn.isnull().sum()/len(data.Tn)*100,'%')
# Out:
# percentage of missing values in Tn 3.9681637293917 %
# percentage of missing values in Tx 6.403909955622683 %
# percentage of missing values in Tavg 7.654450883728034 %
# percentage of missing values in RH_avg 8.17662681476076 %
# percentage of missing values in RR 21.278032803577336 %
# percentage of missing values in ss 7.419582021671064 %
# percentage of missing values in ff_x 1.7333457782152344 %
# percentage of missing values in ddd_x 2.227860130840963 %
# percentage of missing values in Tn 3.9681637293917 %

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#droping columns
data_1=data.drop(columns='station_id')
data_1
# Out:
#              date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0      2010-01-01  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1      2010-02-01  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2      2010-03-01  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3      2010-04-01  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4      2010-05-01  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
# ...           ...   ...   ...   ...     ...   ...  ...   ...    ...     ...
# 589260 2020-12-27  25.2  31.2  29.2    74.0   0.0  1.4   4.0  280.0     2.0
# 589261 2020-12-28  25.3  31.6  28.1    78.0   NaN  3.0  12.0  260.0     2.0
# 589262 2020-12-29  24.6  32.3  28.4    81.0   NaN  6.5   5.0  260.0     2.0
# 589263 2020-12-30  25.2  32.6  28.4    80.0   0.0  2.4   7.0  260.0     2.0
# 589264 2020-12-31  24.3  32.0  26.7    86.0  26.6  5.8   7.0  350.0     2.0
#
#         ddd_car
# 0           NaN
# 1           NaN
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589265 entries, 0 to 589264
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     589265 non-null  datetime64[ns]
#  1   Tn       565882 non-null  float64
#  2   Tx       551529 non-null  float64
#  3   Tavg     544160 non-null  float64
#  4   RH_avg   541083 non-null  float64
#  5   RR       463881 non-null  float64
#  6   ss       545544 non-null  float64
#  7   ff_x     579051 non-null  float64
#  8   ddd_x    576137 non-null  float64
#  9   ff_avg   579138 non-null  float64
#  10  ddd_car  0 non-null       float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 49.5 MB

# %%
cols=data_1.columns
colours = ['#000099', '#ffff00']
sns.heatmap(data_1[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
data_2=data_1.drop(columns='ddd_car')
data_2
# Out:
#              date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg
# 0      2010-01-01  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1      2010-02-01  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2      2010-03-01  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3      2010-04-01  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4      2010-05-01  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
# ...           ...   ...   ...   ...     ...   ...  ...   ...    ...     ...
# 589260 2020-12-27  25.2  31.2  29.2    74.0   0.0  1.4   4.0  280.0     2.0
# 589261 2020-12-28  25.3  31.6  28.1    78.0   NaN  3.0  12.0  260.0     2.0
# 589262 2020-12-29  24.6  32.3  28.4    81.0   NaN  6.5   5.0  260.0     2.0
# 589263 2020-12-30  25.2  32.6  28.4    80.0   0.0  2.4   7.0  260.0     2.0
# 589264 2020-12-31  24.3  32.0  26.7    86.0  26.6  5.8   7.0  350.0     2.0
#
# [589265 rows x 10 columns]

# %%
data_2.isnull().sum()
# Out:
# date           0
# Tn         23383
# Tx         37736
# Tavg       45105
# RH_avg     48182
# RR        125384
# ss         43721
# ff_x       10214
# ddd_x      13128
# ff_avg     10127
# dtype: int64

# %%
data_2['Tn'].skew()
# Out:
# 0.039166351293643625

# %%
Tn_mean=data_2['Tn'].mean()
Tn_mean
# Out:
# 23.312110652043685

# %%
data_2['Tn']=data_2.Tn.fillna(Tn_mean)

# %%
data_2.isnull().sum()
# Out:
# date           0
# Tn             0
# Tx         37736
# Tavg       45105
# RH_avg     48182
# RR        125384
# ss         43721
# ff_x       10214
# ddd_x      13128
# ff_avg     10127
# dtype: int64

# %%
data_2['Tx'].skew()
# Out:
# 13.340565946669157

# %%
sns.distplot(data_2['Tx'],bins=50,hist=True)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tx', ylabel='Density'>

# %%
Tx_median=data_2['Tn'].median()
Tx_median
# Out:
# 24.0

# %%
data_2['Tx']=data_2.Tx.fillna(Tx_median)

# %%
data_2['Tavg'].skew()
# Out:
# -0.814340753839951

# %%
Tavg_median=data_2['Tavg'].median()
Tavg_median
# Out:
# 27.2

# %%
sns.distplot(data_2['Tavg'])
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tavg', ylabel='Density'>

# %%
data_2['Tavg']=data_2.Tavg.fillna(Tavg_median)

# %%
data_2['RH_avg'].skew()
# Out:
# 344.08672401188664

# %%
RH_avg_median=data_2['RH_avg'].median()
RH_avg_median
# Out:
# 83.0

# %%
data_2['RH_avg']=data_2.RH_avg.fillna(RH_avg_median)

# %%
data_2.isnull().sum()
# Out:
# date           0
# Tn             0
# Tx             0
# Tavg           0
# RH_avg         0
# RR        125384
# ss         43721
# ff_x       10214
# ddd_x      13128
# ff_avg     10127
# dtype: int64

# %%
data_2['RR'].skew()
# Out:
# 9.127699420248694

# %%
RR_median=data_2.RR.median()
RR_median
# Out:
# 1.0

# %%
data_2['RR']=data_2.RR.fillna(RR_median)

# %%
data['ss'].skew()
# Out:
# 19.79750431840498

# %%
ss_median=data_2.ss.median()
ss_median
# Out:
# 5.3

# %%
data_2['ss']=data_2.ss.fillna(ss_median)

# %%
data_2['ddd_x'].skew()
# Out:
# 0.2004231816831211

# %%
ddd_x_mean=data_2['ddd_x'].mean()
ddd_x_mean
# Out:
# 188.48832482551893

# %%
data_2['ddd_x']=data_2.ddd_x.fillna(ddd_x_mean)

# %%
data_2['ff_x'].skew()
# Out:
# 14.474509411672242

# %%
ff_x_median=data_2['ff_x'].median()
ff_x_median
# Out:
# 4.0

# %%
data_2['ff_x']=data_2.ff_x.fillna(ff_x_median)

# %%
data_2['ff_avg'].skew()
# Out:
# 14.779358223729247

# %%
ff_avg_median=data_2['ff_avg'].median()
ff_avg_median
# Out:
# 2.0

# %%
data_2['ff_avg']=data_2.ff_avg.fillna(ff_avg_median)

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589265 entries, 0 to 589264
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    589265 non-null  datetime64[ns]
#  1   Tn      589265 non-null  float64
#  2   Tx      589265 non-null  float64
#  3   Tavg    589265 non-null  float64
#  4   RH_avg  589265 non-null  float64
#  5   RR      589265 non-null  float64
#  6   ss      589265 non-null  float64
#  7   ff_x    589265 non-null  float64
#  8   ddd_x   589265 non-null  float64
#  9   ff_avg  589265 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 45.0 MB

# %% [markdown]
# # outliers detection

# %%
box=sns.boxplot(data=data_2)

# %%
fig=plt.figure(figsize=(6,6))
box_1=plt.boxplot(data_2['Tn'].dropna())

# %%
type(box_1)
for i,j in box_1.items():
    print(i,j)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x00000224036CE550>, <matplotlib.lines.Line2D object at 0x00000224036CE820>]
# caps [<matplotlib.lines.Line2D object at 0x00000224036CEAF0>, <matplotlib.lines.Line2D object at 0x00000224036CEDC0>]
# boxes [<matplotlib.lines.Line2D object at 0x00000224036CE280>]
# medians [<matplotlib.lines.Line2D object at 0x00000224036DB0D0>]
# fliers [<matplotlib.lines.Line2D object at 0x00000224036DB3A0>]
# means []

# %%
Tn_outliers=[item.get_ydata() for item in box_1['fliers']]
Tn_outliers
# Out:
# [array([20. , 20. , 20.1, ..., 28. , 28. , 28. ])]

# %%
box_2=plt.boxplot(data_2['Tx'])

# %%
type(box_2)
for i,j in b0x_2.items():
    print(i,j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3292\2485094170.py in <module>
#       1 type(box_2)
# ----> 2 for i,j in b0x_2.items():
#       3     print(i,j)
#
# NameError: name 'b0x_2' is not defined

# %%
Tx_outliers=[item.get_ydata() for item in box_2['fliers']]
Tx_outliers

# %%
box_3=plt.boxplot(data_2['Tavg'])

# %%
type(box_3)
for i,j in box_3.items():
    print(i,j)

# %%
Tavg_outliers=[item.get_ydata() for item in box_1['fliers']]
Tavg_outliers

# %%
#a=pd.Series({'outliers':[Tavg_outliers]})
#a

# %%
#b=pd.DataFrame(a)
#b

# %%
box_4=plt.boxplot(data_2['RH_avg'])

# %%
type(box_4)
for i,j in box_4.items():
    print(i,j)

# %%
RH_avg_outliers=[item.get_ydata() for item in box_2['fliers']]
RH_avg_outliers

# %%
# correlation analysis and scatter plot
sns.pairplot(data_2)

# %%
data_2.corr()
# Out:
#               Tn        Tx      Tavg    RH_avg        RR        ss      ff_x  \
# Tn      1.000000  0.354209  0.712245 -0.020649 -0.049216  0.050056  0.076542
# Tx      0.354209  1.000000  0.523276 -0.147110 -0.106285  0.171325  0.081813
# Tavg    0.712245  0.523276  1.000000 -0.175998 -0.133055  0.191976  0.083946
# RH_avg -0.020649 -0.147110 -0.175998  1.000000  0.124552 -0.162554 -0.082328
# RR     -0.049216 -0.106285 -0.133055  0.124552  1.000000 -0.171731 -0.031319
# ss      0.050056  0.171325  0.191976 -0.162554 -0.171731  1.000000  0.074004
# ff_x    0.076542  0.081813  0.083946 -0.082328 -0.031319  0.074004  1.000000
# ddd_x   0.021155 -0.007325 -0.025943  0.039691  0.051831 -0.068816  0.044733
# ff_avg  0.049827  0.015090  0.065041 -0.093350 -0.054202  0.064630  0.366361
#
#            ddd_x    ff_avg
# Tn      0.021155  0.049827
# Tx     -0.007325  0.015090
# Tavg   -0.025943  0.065041
# RH_avg  0.039691 -0.093350
# RR      0.051831 -0.054202
# ss     -0.068816  0.064630
# ...

# %%
import sweetviz as sv
sweet_report = sv.analyze(data)
sweet_report.show_html('weather_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# C:\Users\lenovo\anaconda3\lib\site-packages\sweetviz\series_analyzer.py:16: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts_without_nan = pd.Series()
# Report weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
